# %%
import os
os.environ["gemini-api-key"] = "AIzaSyAo_TDBVSOgA19pZVTyEXcfGcpIR4C5v_8"

# %% [markdown]
# ## Install Libraries

# %%
# !pip install --user youtube-transcript-api langchain-community langchain-google-genai faiss-cpu tiktoken python-dotenv
# Out:
# Access is denied.

# %%
import sys
print(sys.executable)
# Out:
# C:\ProgramData\anaconda3\python.exe
